# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import joblib

# %%
df = pd.read_csv("deemanding_job.csv")

# %%
df.head()
# Out:
#                           interest  \
# 0  Computer science and technology
# 1  Computer science and technology
# 2  Computer science and technology
# 3  Computer science and technology
# 4  Computer science and technology
#
#                                               skills  \
# 0  Python, Numpy, Pandas, Scikit-Learn, TensorFlo...
# 1     HTML, CSS, JavaScript, React, Angular, Node.js
# 2  Java, Spring, Hibernate, REST APIs, Microservices
# 3    React, Redux, TypeScript, JavaScript, HTML, CSS
# 4  SQL, Tableau, Excel, Power BI, Data Visualization
#
#                     job_role
# 0  Machine Learning Engineer
# 1         Frontend Developer
# 2          Backend Developer
# 3       Full Stack Developer
# 4               Data Analyst

# %%
df["skills"] = df["skills"].str.lower().str.replace(",", "")

# %% [markdown]
# ### Feature Engineering

# %%
# Encode job roles
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df["job_role"])

# %%
# Encode interest
interest_encoder = LabelEncoder()
df["interest_encoded"] = interest_encoder.fit_transform(df["interest"])

# %%
df.head()
# Out:
#                           interest  \
# 0  Computer science and technology
# 1  Computer science and technology
# 2  Computer science and technology
# 3  Computer science and technology
# 4  Computer science and technology
#
#                                               skills  \
# 0  python numpy pandas scikit-learn tensorflow keras
# 1          html css javascript react angular node.js
# 2      java spring hibernate rest apis microservices
# 3         react redux typescript javascript html css
# 4      sql tableau excel power bi data visualization
#
#                     job_role  interest_encoded
# 0  Machine Learning Engineer                 2
# 1         Frontend Developer                 2
# 2          Backend Developer                 2
# 3       Full Stack Developer                 2
# 4               Data Analyst                 2

# %%
# Features
X = df[["skills", "interest_encoded"]]

# %%
# Create a column transformer to handle different feature types
preprocessor = ColumnTransformer(
    transformers=[
        ('text', CountVectorizer(stop_words='english'), 'skills'),
        ('cat', OneHotEncoder(), ['interest_encoded'])
    ]
)

# %%
# Create a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=42))
])

# %%
# Train the model
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('text',
#                                                   CountVectorizer(stop_words='english'),
#                                                   'skills'),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['interest_encoded'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
# Save the model and label encoders
joblib.dump({
    'pipeline': pipeline,
    'label_encoder': label_encoder,
    'interest_encoder': interest_encoder,
    'X': X,
    'y': y
}, 'deemanding_job_model.joblib')

print("Model saved successfully.")
# Out:
# Model saved successfully.
